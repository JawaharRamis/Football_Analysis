# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects
from matplotlib import rcParams
from highlight_text import ax_text, fig_text
import pandas as pd
import soccerdata as sd
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from adjustText import adjust_text


from PIL import Image
import urllib
import os

# %%
SEASON ='2022-23'

# %%
# --- Use this only if you have already downloaded fonts into your
# --- local directory.

# Add pretty fonts

# font_path = r"" #Set the path to where the fonts are located

# for x in os.listdir(font_path):
#     for y in os.listdir(f"{font_path}/{x}"):
#         if y.split(".")[-1] == "ttf":
#             fm.fontManager.addfont(f"{font_path}/{x}/{y}")
#             try:
#                 fm.FontProperties(weight=y.split("-")[-1].split(".")[0].lower(), fname=y)
#             except Exception as e:
#                 print(f"Font {y} could not be added.")
#                 continue

rcParams['font.family'] = 'Karla'

# %%
fbref = sd.FBref(leagues="ENG-Premier League", seasons=2022)
# df = fbref.read_team_season_stats(stat_type='passing')
df = fbref.read_player_season_stats(stat_type="possession")
df.head()
# Out:
# [09/19/22 19:55:49] INFO     Saving cached data to C:\Users\jawah\soccerdata\data\FBref               ]8;id=47793;file://C:\Users\jawah\anaconda3\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=727633;file://C:\Users\jawah\anaconda3\lib\site-packages\soccerdata\_common.py#89\89]8;;\
# https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# https://fbref.com/en/squads/8602292d/Aston-Villa-Stats
# https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats
# https://fbref.com/en/squads/cd051869/Brentford-Stats
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# https://fbref.com/en/squads/fd962109/Fulham-Stats
# https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats
# https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats
# https://fbref.com/en/squads/33c895d4/Southampton-Stats
# https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats
#                                                        Nation Pos     Age  \
#
# league             season team    player
# ENG-Premier League 2223   Arsenal Aaron Ramsdale          ENG  GK  24-121
#                                   Albert Sambi Lokonga    BEL  MF  22-325
#                                   Ben White               ENG  DF  24-339
#                                   Bukayo Saka             ENG  FW  21-007
#                                   Eddie Nketiah           ENG  FW  23-105
#
#                                                         90s Touches          \
#                                                             Touches Def Pen
# league             season team    player
# ENG-Premier League 2223   Arsenal Aaron Ramsdale        6.0     188     147
#                                   Albert Sambi Lokonga  1.9     111       6
#                                   Ben White             5.2     385      11
#                                   Bukayo Saka           5.9     304       2
#                                   Eddie Nketiah         0.9      44       1
#
#                                                                         \
#                                                        Def 3rd Mid 3rd
# league             season team    player
# ENG-Premier League 2223   Arsenal Aaron Ramsdale           187       2
#                                   Albert Sambi Lokonga      24      77
#                                   Ben White                101     215
#                                   Bukayo Saka               29     110
#                                   Eddie Nketiah              6      18
#
#                                                                         ...  \
#                                                        Att 3rd Att Pen  ...
# league             season team    player                                ...
# ENG-Premier League 2223   Arsenal Aaron Ramsdale             0       0  ...
#                                   Albert Sambi Lokonga      18       0  ...
#                                   Ben White                 91       4  ...
#                                   Bukayo Saka              192      44  ...
#                                   Eddie Nketiah             25       8  ...
#
#                                                        Carries               \
#                                                        PrgDist Prog 1/3 CPA
# league             season team    player
# ENG-Premier League 2223   Arsenal Aaron Ramsdale           288    0   0   0
#                                   Albert Sambi Lokonga     171    8   4   0
#                                   Ben White                604   23   9   0
#                                   Bukayo Saka              834   51  16  14
#                                   Eddie Nketiah            174    3   2   1
#
#                                                                Receiving       \
#                                                        Mis Dis      Targ  Rec
# league             season team    player
# ENG-Premier League 2223   Arsenal Aaron Ramsdale         0   0       100  100
#                                   Albert Sambi Lokonga   1   1        81   79
#                                   Ben White              3   0       261  253
#                                   Bukayo Saka            7  11       277  214
#                                   Eddie Nketiah          5   1        52   34
#
#
#                                                          Rec% Prog
# league             season team    player
# ENG-Premier League 2223   Arsenal Aaron Ramsdale        100.0    0
#                                   Albert Sambi Lokonga   97.5    0
#                                   Ben White              96.9    3
#                                   Bukayo Saka            77.3   47
#                                   Eddie Nketiah          65.4    9
#
# [5 rows x 28 columns]

# %%
df = df.reset_index()
df = df.drop(columns=['team', 'season', 'league'])
df
# Out:
# C:\Users\jawah\AppData\Local\Temp\ipykernel_26572\35640453.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(columns=['team', 'season', 'league'])
#                    player Nation  Pos     Age  90s Touches                  \
#                                                    Touches Def Pen Def 3rd
# 0          Aaron Ramsdale    ENG   GK  24-121  6.0     188     147     187
# 1    Albert Sambi Lokonga    BEL   MF  22-325  1.9     111       6      24
# 2               Ben White    ENG   DF  24-339  5.2     385      11     101
# 3             Bukayo Saka    ENG   FW  21-007  5.9     304       2      29
# 4           Eddie Nketiah    ENG   FW  23-105  0.9      44       1       6
# ..                    ...    ...  ...     ...  ...     ...     ...     ...
# 441       Rayan Aït Nouri    FRA   DF  21-098  4.1     295      16      88
# 442          Raúl Jiménez    MEX   FW  31-130  2.4      64       4       7
# 443           Rúben Neves    POR   MF  25-183  6.0     460      39     151
# 444        Sasa Kalajdzic    AUT   FW  25-067  0.5       7       0       2
# 445           Squad Total   None  NaN    26.2  6.0    3805     472    1378
#
#                      ... Carries                      Receiving               \
#     Mid 3rd Att 3rd  ... PrgDist Prog 1/3 CPA Mis Dis      Targ   Rec   Rec%
# 0         2       0  ...     288    0   0   0   0   0       100   100  100.0
# 1        77      18  ...     171    8   4   0   1   1        81    79   97.5
# 2       215      91  ...     604   23   9   0   3   0       261   253   96.9
# 3       110     192  ...     834   51  16  14   7  11       277   214   77.3
# 4        18      25  ...     174    3   2   1   5   1        52    34   65.4
# ..      ...     ...  ...     ...  ...  ..  ..  ..  ..       ...   ...    ...
# 441     113     107  ...     482   30   7   1   4   7       213   195   91.5
# 442      23      38  ...     103    5   2   2   6   7        83    46   55.4
# 443     250      84  ...     497   14   7   0   5   6       274   264   96.4
# 444       1       4  ...       0    0   0   0   0   0        18     4   22.2
# 445    1584    1081  ...    7263  263  80  23  87  64      2850  2498   87.6
#
#
#     Prog
# 0      0
# 1      0
# 2      3
# 3     47
# 4      9
# ..   ...
# 441   15
# 442   18
# 443    5
# 444    1
# 445  201
#
# [446 rows x 29 columns]

# %%
players = [
    'Mohamed Salah',
    'Gabriel Jesus',
    'Bukayo Saka',
    'Erling Haaland',
    'Aleksandar Mitrović',
    'Wilfried Zaha',
    'Danny Welbeck',
    'Jarrod Bowen',
    'Harry Kane',
    'Dejan Kulusevski',
    'Ivan Toney',
    'Marcus Rashford',
    'Kevin De Bruyne', 
    'Erling Haaland',
    'Allan Saint-Maximin',
    'Anthony Gordon',
    'Raheem Sterling',
    'Martinelli'
]

# filtered_df = 
df.columns
# Out:
# MultiIndex([(   'player',        ''),
#             (   'Nation',        ''),
#             (      'Pos',        ''),
#             (      'Age',        ''),
#             (      '90s',        ''),
#             (  'Touches', 'Touches'),
#             (  'Touches', 'Def Pen'),
#             (  'Touches', 'Def 3rd'),
#             (  'Touches', 'Mid 3rd'),
#             (  'Touches', 'Att 3rd'),
#             (  'Touches', 'Att Pen'),
#             (  'Touches',    'Live'),
#             ( 'Dribbles',    'Succ'),
#             ( 'Dribbles',     'Att'),
#             ( 'Dribbles',   'Succ%'),
#             ( 'Dribbles',     '#Pl'),
#             ( 'Dribbles',    'Megs'),
#             (  'Carries', 'Carries'),
#             (  'Carries', 'TotDist'),
#             (  'Carries', 'PrgDist'),
#             (  'Carries',    'Prog'),
#             (  'Carries',     '1/3'),
#             (  'Carries',     'CPA'),
#             (  'Carries',     'Mis'),
#             (  'Carries',     'Dis'),
#             ('Receiving',    'Targ'),
#             ('Receiving',     'Rec'),
#             ('Receiving',    'Rec%'),
#             ('Receiving',    'Prog')],
#            )

# %%
# df[df['Pos'].find('FW') == -1]
df['Pos'] = df['Pos'].fillna('XX')
df = df[df['Pos'].str.contains("FW")]

# %%
df_main = df[~df["player"].isin(players)].reset_index(drop = True)
df_highlight = df[df["player"].isin(players)].reset_index(drop = True)
df_highlight
# Out:
#                  player Nation    Pos     Age  90s Touches                  \
#                                                    Touches Def Pen Def 3rd
# 0           Bukayo Saka    ENG     FW  21-007  5.9     304       2      29
# 1         Gabriel Jesus    BRA     FW  25-162  5.8     285       1      15
# 2            Martinelli    BRA     FW  21-086  5.8     282       1      12
# 3            Ivan Toney    ENG     FW  26-180  6.0     197       6      17
# 4         Danny Welbeck    ENG     FW  31-290  5.3     157       3       5
# 5       Raheem Sterling    ENG  FW,MF  27-278  5.7     245       1       8
# 6         Wilfried Zaha    CIV  FW,MF  29-306  4.9     216       2      21
# 7        Anthony Gordon    ENG     FW  21-200  5.9     241       7      44
# 8   Aleksandar Mitrović    SRB     FW  27-361  6.0     221       9      30
# 9         Mohamed Salah    EGY     FW  30-089  6.0     263       0       6
# 10       Erling Haaland    NOR     FW  22-053  5.3     128       2       4
# 11      Marcus Rashford    ENG     FW  24-316  5.8     202       3      16
# 12  Allan Saint-Maximin    FRA     FW  25-184  3.8     180       0      15
# 13     Dejan Kulusevski    SWE  MF,FW  22-140  4.8     209       9      36
# 14           Harry Kane    ENG     FW  29-046  5.9     231       4      19
# 15         Jarrod Bowen    ENG     FW  25-266  5.9     194       7      29
#
#                     ... Carries                      Receiving
#    Mid 3rd Att 3rd  ... PrgDist Prog 1/3 CPA Mis Dis      Targ  Rec  Rec% Prog
# 0      110     192  ...     834   51  16  14   7  11       277  214  77.3   47
# 1      120     168  ...     388   18   8   4  22  22       302  214  70.9   61
# 2       96     192  ...     668   45  10  10  14  11       257  202  78.6   51
# 3       92      95  ...      81    3   0   0  15   9       236  144  61.0   28
# 4       49     108  ...     215   16   4   2  22   5       221  123  55.7   42
# 5       85     169  ...     515   36   7  10  18  27       288  207  71.9   51
# 6      110     107  ...     560   34  12   9  21  18       235  159  67.7   40
# 7      108     115  ...     608   27   9  12  13  24       244  156  63.9   23
# 8      106      99  ...     241   14   2   4  26  18       321  162  50.5   21
# 9       59     208  ...     489   38   6  13  14  24       343  210  61.2   61
# 10      53      72  ...     102    8   1   5  10   3       187  100  53.5   40
# 11      92     106  ...     374   27   4   9  17   7       264  165  62.5   40
# 12      67     125  ...     957   51  18  11   7  13       167  143  85.6   28
# 13      89     110  ...     986   41  18  16  12  11       192  150  78.1   31
# 14     131      93  ...     419   27   9   3  15  17       271  178  65.7   37
# 15      71     111  ...     263   19   1   4  10   9       188  118  62.8   26
#
# [16 rows x 29 columns]

# %%
# -- Plot the chart


x_param = df['Touches']['Att Pen']
y_param = df['Carries']['1/3']


fig = plt.figure(figsize = (7,5), dpi = 300)
ax = plt.subplot(facecolor = "#e9edcc")

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.scatter(
    df_main['Touches']['Att Pen'], 
    df_main['Carries']['1/3'], 
    s = 40, 
    alpha = 0.6, 
    color = "#780b68",
    zorder = 3
)

ax.scatter(
    df_highlight['Touches']['Att Pen'], 
    df_highlight['Carries']['1/3'], 
    s = 50, 
    alpha = 0.95, 
    color = "#F64740",
    zorder = 3,
    ec = "#000000",
)


ax.plot(
    [ x_param.median(), x_param.median()],
    [ax.get_ylim()[0], ax.get_ylim()[1]], 
    ls = ":",
    color = "#b82ea5",
    zorder = 2
)

ax.plot(
    [ax.get_xlim()[0], ax.get_xlim()[1]],
    [ y_param.median(),  y_param.median()], 
    ls = ":",
    color = "#b82ea5",
    zorder = 2
)

ax.grid(True, ls = ":", color = "#4e590b")


texts = []

for index, name in enumerate(df_highlight["player"]):
    X = df_highlight['Touches']['Att Pen'].iloc[index]
    Y = df_highlight['Carries']['1/3'].iloc[index]
    texts.append(plt.text(X,Y, name, color ='#c8f7c8', fontweight='medium', size='small'))
#     text_ = ax.annotate(
#         xy = (X, Y),
#         text = name.split(" ")[1],
#         ha = "center",
#         va = "center",
#         xytext = (0, 10),
#         textcoords = "offset points",
#         weight = "bold"
#     )

    text_.set_path_effects(
                [path_effects.Stroke(linewidth=2.5, foreground="white"), 
                path_effects.Normal()]
            )
adjust_text(texts, precision=0.001,
        expand_text=(1.01, 1.05), expand_points=(1.01, 1.05),
        force_text=(0.01, 0.25), force_points=(0.01, 0.25))
ax.set_xlabel("Touches in Penalty box")
ax.set_ylabel("Progressive carries in final third")

ax.spines['bottom'].set_color('#c8f7c8')
ax.spines['left'].set_color('#c8f7c8')
ax.xaxis.label.set_color('#c8f7c8')
ax.yaxis.label.set_color('#c8f7c8')
ax.tick_params(axis='x', colors='#c8f7c8')
ax.tick_params(colors='#c8f7c8')

fig_text(
    x = 0.9, y = 0.9, 
    s = "<Premier League> forwards | Season <%s>\n <Touches in Penalty box> vs <Progressive carries in final third> " %(SEASON),
    highlight_textprops=[{"color":"#F64740", "style":"italic"},
                         {"color":"#F64740", "style":"italic"},
                        {"color":"#F64740", "style":"italic", "fontsize" : "8"}, 
                         {"color":"#F64740", "style":"italic", "fontsize" : "8"}],
    va = "bottom", ha = "right",
    fontsize = 12, color = "#c8f7c8", font = "Karla", weight = "bold"
)

image_ax = fig.add_axes(
        [0.14,0.85, .22, .15],
        fc='#031738', 
    )

logo_dir = './assets/logos/PL/Premier League.png'
club_icon = Image.open(logo_dir)
# club_icon = np.array(club_icon).astype(np.float) / 255

image_ax.imshow(club_icon)
image_ax.axis('off')


plt.savefig(
	"scatter_players.png",
	dpi = 600,
	facecolor = "#031738",
	bbox_inches="tight",
    edgecolor="none",
	transparent = True
)
